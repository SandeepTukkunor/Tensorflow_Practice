# %%
import matplotlib.pyplot as plt

# %%
import seaborn as sns
import pandas as pd
import numpy as np

# %%
x = [0,1,2]
y = [100,200,300]

# %%
plt.plot(x,y)
plt.show()

# %%
#couple of basic tools 
housing = pd.DataFrame({'rooms' :[1,1,2,2,2,3,3,3],
                        'price':[100,120,190,200,230,310,330,305]})

# %%
housing
# Out:
#    rooms  price
# 0      1    100
# 1      1    120
# 2      2    190
# 3      2    200
# 4      2    230
# 5      3    310
# 6      3    330
# 7      3    305

# %%
#scatter plot
plt.scatter(housing['rooms'],housing['price'])

# %%
#recall 
#here we are trying to add lables and titles
plt.title("Title")
plt.xlabel("X-label")
plt.ylabel("Y-label")
plt.plot(x,y)
#limit axis limits
plt.xlim(0,2)#x-axis limits
plt.ylim(0,300)


#add colors and markers
plt.plot(x,y, color = 'red', marker = 'o', markersize = 15, linestyle = "--")
